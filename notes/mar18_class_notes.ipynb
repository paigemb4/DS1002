# %% [markdown]
# <a href="https://colab.research.google.com/github/paigemb4/DS1002/blob/main/notes/mar18_class_notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# data cleaning

# %%
import pandas as pd
import numpy as np

# %%
dupes = pd.read_csv('./dupe-vals.csv')

# %%
dupes.duplicated()
#first time it sees something duplicates it doesn't realize its a duplicate (true when duplicate)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 116     True
# 117     True
# 118     True
# 119     True
# 120     True
# Length: 121, dtype: bool

# %%
print(dupes.duplicated().sum())
#total of duplicate rows
# Out:
# 0

# %%
dupes = dupes.drop_duplicates()
#removes duplicate rows

# %%
dupes
# Out:
#            pickup        dropoff  passengers  distance  fare   tip  tolls  \
# 0   3/23/19 20:21  3/23/19 20:27           1      1.60   7.0  2.15    0.0
# 1    3/4/19 16:11   3/4/19 16:19           1      0.79   5.0  0.00    0.0
# 2   3/27/19 17:53  3/27/19 18:00           1      1.37   7.5  2.36    0.0
# 3    3/10/19 1:23   3/10/19 1:49           1      7.70  27.0  6.15    0.0
# 4   3/30/19 13:27  3/30/19 13:37           3      2.16   9.0  1.10    0.0
# ..            ...            ...         ...       ...   ...   ...    ...
# 95  3/28/19 21:30  3/28/19 21:42           1      1.60   9.0  2.55    0.0
# 96  3/13/19 16:11  3/13/19 16:28           1      3.21  13.5  0.00    0.0
# 97   3/4/19 22:34   3/4/19 22:41           1      1.30   7.5  0.50    0.0
# 98   3/8/19 19:10   3/8/19 19:18           2      0.90   7.0  0.00    0.0
# 99   3/2/19 10:47   3/2/19 10:56           3      0.95   7.5  2.16    0.0
#
#     total   color      payment                   pickup_zone  \
# 0   12.95  yellow  credit card               Lenox Hill West
# 1    9.30  yellow         cash         Upper West Side South
# 2   14.16  yellow  credit card                 Alphabet City
# 3   36.95  yellow  credit card                     Hudson Sq
# 4   13.40  yellow  credit card                  Midtown East
# ..    ...     ...          ...                           ...
# 95  15.35  yellow  credit card  Penn Station/Madison Sq West
# 96  17.80  yellow         cash      Financial District South
# 97  11.80  yellow  credit card                Midtown Center
# 98  11.30  yellow         cash                 Midtown North
# 99  12.96  yellow  credit card                  West Village
#
#                       dropoff_zone pickup_borough dropoff_borough
# 0              UN/Turtle Bay South      Manhattan       Manhattan
# 1            Upper West Side South      Manhattan       Manhattan
# 2                     West Village      Manhattan       Manhattan
# 3                   Yorkville West      Manhattan       Manhattan
# 4                   Yorkville West      Manhattan       Manhattan
# ..                             ...            ...             ...
# 95  Stuy Town/Peter Cooper Village      Manhattan       Manhattan
# 96     Downtown Brooklyn/MetroTech      Manhattan        Brooklyn
# 97           Upper East Side South      Manhattan       Manhattan
# 98       Times Sq/Theatre District      Manhattan       Manhattan
# 99                        Flatiron      Manhattan       Manhattan
#
# [100 rows x 14 columns]

# %% [markdown]
# working w/ missing data

# %%
df_miss = pd.DataFrame({
    'x':[2, np.nan, 1],
    'y':[np.nan, np.nan, 6],
    'z':[4, np.nan, np.nan]}
)
#nan stands for not a number

# %%
df_miss
# Out:
#      x    y    z
# 0  2.0  NaN  4.0
# 1  NaN  NaN  NaN
# 2  1.0  6.0  NaN

# %%
df_drop_all = df_miss.dropna()
df_drop_all
#.dropna() drops all the rows with nan
# Out:
# Empty DataFrame
# Columns: [x, y, z]
# Index: []

# %%
df_drop_x = df_miss.dropna(subset=['x'])
df_drop_x
#specifies which columns to pay attentions to, here only drops where x variable has nan
# Out:
#      x    y    z
# 0  2.0  NaN  4.0
# 2  1.0  6.0  NaN

# %%
df_filled = df_miss.fillna(df_miss.median())
df_filled
#.fillna fills missing data
# Out:
#      x    y    z
# 0  2.0  6.0  4.0
# 1  1.5  6.0  4.0
# 2  1.0  6.0  4.0

# %% [markdown]
# practice w/another file:

# %%
practice= pd.read_csv('./very-messy-data.csv')

# %%
practice
# Out:
#        id  sepal_length  sepal_width  petal_length  petal_width    species
# 0       1           3.5          2.9           1.4          0.5  virginica
# 1       2           3.6          3.2           3.0          0.5     setosa
# 2       3           3.8          NaN           2.2          1.5     setosa
# 3       4           5.8          2.7           2.6          1.2  virginica
# 4       5           4.9          3.6           3.0          1.2  virginica
# ...   ...           ...          ...           ...          ...        ...
# 1311  412           NaN          3.6           2.9          0.5  virginica
# 1312  413           5.8          2.7           2.0          0.1  virginica
# 1313  414           3.3          3.7           1.3          2.8     setosa
# 1314  415           3.1          NaN           1.1          NaN  virginica
# 1315  416           4.3          2.5           1.3          1.0     setosa
#
# [1316 rows x 6 columns]

# %%
practice.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1311     True
# 1312     True
# 1313     True
# 1314     True
# 1315     True
# Length: 1316, dtype: bool

# %%
print(practice.duplicated().sum())
# Out:
# 316

# %%
practice1= practice.drop_duplicates()
print(practice1.duplicated().sum())
# Out:
# 0

# %%
practice1
# Out:
#        id  sepal_length  sepal_width  petal_length  petal_width    species
# 0       1           3.5          2.9           1.4          0.5  virginica
# 1       2           3.6          3.2           3.0          0.5     setosa
# 2       3           3.8          NaN           2.2          1.5     setosa
# 3       4           5.8          2.7           2.6          1.2  virginica
# 4       5           4.9          3.6           3.0          1.2  virginica
# ..    ...           ...          ...           ...          ...        ...
# 995   996           4.5          3.6           NaN          2.7     setosa
# 996   997           4.0          2.1           NaN          2.1     setosa
# 997   998           5.9          2.5           2.1          2.5  virginica
# 998   999           5.0          2.6           1.9          NaN        NaN
# 999  1000           3.4          3.9           1.9          1.5     setosa
#
# [1000 rows x 6 columns]

# %%
practice1_drop_all = practice1.dropna()
practice1_drop_all
# Out:
#        id  sepal_length  sepal_width  petal_length  petal_width    species
# 0       1           3.5          2.9           1.4          0.5  virginica
# 1       2           3.6          3.2           3.0          0.5     setosa
# 3       4           5.8          2.7           2.6          1.2  virginica
# 4       5           4.9          3.6           3.0          1.2  virginica
# 5       6           5.0          2.7           1.4          2.3     setosa
# ..    ...           ...          ...           ...          ...        ...
# 991   992           3.7          2.5           2.6          2.8  virginica
# 993   994           4.5          3.7           1.2          0.3  virginica
# 994   995           4.0          2.9           1.0          0.2  virginica
# 997   998           5.9          2.5           2.1          2.5  virginica
# 999  1000           3.4          3.9           1.9          1.5     setosa
#
# [608 rows x 6 columns]

# %%
practice1_filled = practice1.fillna(df_miss.mean())
practice1_filled
# Out:
#        id  sepal_length  sepal_width  petal_length  petal_width    species
# 0       1           3.5          2.9           1.4          0.5  virginica
# 1       2           3.6          3.2           3.0          0.5     setosa
# 2       3           3.8          NaN           2.2          1.5     setosa
# 3       4           5.8          2.7           2.6          1.2  virginica
# 4       5           4.9          3.6           3.0          1.2  virginica
# ..    ...           ...          ...           ...          ...        ...
# 995   996           4.5          3.6           NaN          2.7     setosa
# 996   997           4.0          2.1           NaN          2.1     setosa
# 997   998           5.9          2.5           2.1          2.5  virginica
# 998   999           5.0          2.6           1.9          NaN        NaN
# 999  1000           3.4          3.9           1.9          1.5     setosa
#
# [1000 rows x 6 columns]

# %% [markdown]
# data type constraints

# %%
sales = pd.read_csv('https://ds1002-resources.s3.amazonaws.com/data/sales.csv')
sales.head(2)
# Out:
#    SalesOrderID Revenue  Quantity
# 0         43659  23153$        12
# 1         43660   1457$         2

# %%
sales['Revenue'].sum()
#calculate revenue, but produces a weird error
# Out:
# 162480

# %%
sales.dtypes
# Out:
# SalesOrderID     int64
# Revenue         object
# Quantity         int64
# dtype: object

# %%
sales.head(20)
# Out:
#     SalesOrderID  Revenue  Quantity
# 0          43659    23153        12
# 1          43660     1457         2
# 2          43661     3857         3
# 3          43662    15748         8
# 4          43663    18067        10
# 5          43664     5978         4
# 6          43665     2985         3
# 7          43666    28567        15
# 8          43667     9865         6
# 9          43668     2314         3
# 10         43669     3459         4
# 11         43670     8736         6
# 12         43671    16732         9
# 13         43672    21562        11

# %%
sales['Revenue'] = sales['Revenue'].str.strip('$')
sales['Revenue'] = sales['Revenue'].astype('int')
#removes the $ from revenue columns, only works once don't be alarmed by the error
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-683d4b133844> in <cell line: 1>()
# ----> 1 sales['Revenue'] = sales['Revenue'].str.strip('$')
#       2 sales['Revenue'] = sales['Revenue'].astype('int')
#       3 #removes the $ from revenue columns
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     180             # we're accessing the attribute of the class, i.e., Dataset.geo
#     181             return self._accessor
# --> 182         accessor_obj = self._accessor(obj)
#     183         # Replace the property with the accessor object. Inspired by:
#     184         # https://www.pydanny.com/cached-property.html
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/strings/accessor.py in __init__(self, data)
#     179         from pandas.core.arrays.string_ import StringDtype
#     180
# --> 181         self._inferred_dtype = self._validate(data)
#     182         self._is_categorical = is_categorical_dtype(data.dtype)
#     183         self._is_string = isinstance(data.dtype, StringDtype)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/strings/accessor.py in _validate(data)
#     233
#     234         if inferred_dtype not in allowed_types:
# --> 235             raise AttributeError("Can only use .str accessor with string values!")
#     236         return inferred_dtype
#     237
#
# AttributeError: Can only use .str accessor with string values!

# %%
sales['Revenue'].dtype == 'int'
# Out:
# True

# %% [markdown]
# numeric/categorical data

# %%
marriage_status = pd.read_csv('https://ds1002-resources.s3.amazonaws.com/data/marriage_status.csv')
marriage_status.head(3)
# Out:
#   marriage_status
# 0        divorced
# 1       separated
# 2         married

# %%
marriage_status.head(50)
# Out:
#    marriage_status
# 0         divorced
# 1        separated
# 2          married
# 3        UNMARRIED
# 4          MARRIED
# 5          MARRIED
# 6          married
# 7        unmarried
# 8        UNMARRIED
# 9         divorced
# 10         married
# 11       separated
# 12         married
# 13       UNMARRIED
# 14       unmarried
# 15        divorced
# 16         married
# 17       separated
# 18       unmarried
# 19       unmarried
# 20         married

# %%
marriage_status['marriage_status'].describe()
# Out:
# count          21
# unique          6
# top       married
# freq            6
# Name: marriage_status, dtype: object

# %%
marriage_status['marriage_status'] = marriage_status['marriage_status'].astype('category')

# %%
marriage_status.describe()
#marriage status is name of data frame but its also a variable
#count- number of values
#unique- 6 unique values
# top- most common value
# freq- how many times the most common value appears
# Out:
#        marriage_status
# count               21
# unique               6
# top            married
# freq                 6

# %%
marriage_status.dtypes
# Out:
# marriage_status    category
# dtype: object

# %%
marriage_status["marriage_status"] = marriage_status["marriage_status"].str.lower()

# %%
marriage_status.describe()
# now have the 4 values we want: married, unmarried, divorced, single
# Out:
#        marriage_status
# count               21
# unique               4
# top            married
# freq                 8

# %% [markdown]
# out of range data

# %%
movies = pd.read_csv('https://ds1002-resources.s3.amazonaws.com/data/movies.csv')
movies.head(10)
# Out:
#                  Name  Year  Score
# 0    Twleve Angry Men  1957    8.9
# 1               Alien  1979    8.4
# 2  American History X  1998    8.5
# 3  Back to the Future  1985    8.5
# 4          Casablanca  1942    8.5
# 5         City of God  2002    8.6
# 6          Fight Club  1999   11.0
# 7        Forrest Gump  1994    8.8
# 8           Gladiator  2000    8.5
# 9          Goodfellas  1990    8.7

# %%
# data viz
import matplotlib.pyplot as plt
plt.hist(movies['Score'])
plt.title('Average rating of top 50 movies (0-10')
# Out:
# Text(0.5, 1.0, 'Average rating of top 50 movies (0-10')

# %%
users = pd.read_csv('https://ds1002-resources.s3.amazonaws.com/data/user_signups.csv')
users.tail()
# Out:
#    subscription_date user_name country
# 7             7/3/23       Leo     USA
# 8             5/1/23      Marc     USA
# 9           10/10/23       Lou     USA
# 10          11/15/23     Sheng     USA
# 11           12/3/23     Nancy     USA

# %%
users.dtypes
# Out:
# subscription_date    object
# user_name            object
# country              object
# dtype: object

# %%
import datetime as dt

users['subscription_date'] = pd.to_datetime(users['subscription_date'])
users.dtypes
#converts object to dates, helpful for the computer to know because there a lot of formats for dates
# Out:
# subscription_date    datetime64[ns]
# user_name                    object
# country                      object
# dtype: object

# %%
users.head()
# Out:
#   subscription_date  user_name country
# 0        2021-01-05     Mariah     USA
# 1        2020-09-09     Joshua     USA
# 2        2020-04-01      Heidi     USA
# 3        2020-11-10  Christine     USA
# 4        2020-11-07     Ayanna     USA

# %%
users['subscription_date'] = pd.to_datetime(users['subscription_date']).dt.date
users.dtypes
# Out:
# subscription_date    object
# user_name            object
# country              object
# dtype: object

# %%
today_date = dt.date.today()
users[users['subscription_date'] > today_date]
# Out:
# Empty DataFrame
# Columns: [subscription_date, user_name, country]
# Index: []

# %% [markdown]
# dealing w/out of range data

# %%
movies[movies['Score'] > 10]
# Out:
#                                                  Name  Year  Score
# 6                                          Fight Club  1999   11.0
# 12                                          Inception  2010   11.0
# 22                                       Pulp Fiction  1994   11.0
# 40  The Lord of the Rings: The Fellowship of the Ring  2001   11.0

# %% [markdown]
# dropping values:

# %%
# by filtering
movies1 = movies[movies.Score <= 10]

#check that values were dropped
movies1.sort_values(['Score'], ascending = False).head()
# Out:
#                         Name  Year  Score
# 46  The Shawshank Redemption  1994    9.2
# 34             The Godfather  1972    9.2
# 32           The Dark Knight  2008    9.0
# 35     The Godfather Part II  1974    9.0
# 0           Twleve Angry Men  1957    8.9

# %%
# with .drop() function
movies2 = movies.drop(movies[movies['Score'] > 10].index)
movies2.sort_values('Score', ascending = False).head()
# Out:
#                         Name  Year  Score
# 46  The Shawshank Redemption  1994    9.2
# 34             The Godfather  1972    9.2
# 32           The Dark Knight  2008    9.0
# 35     The Godfather Part II  1974    9.0
# 0           Twleve Angry Men  1957    8.9

# %%
# convert Score > 10 to 10
movies.loc[movies['Score']> 10, 'Score'] = 10

assert movies['Score'].max() <= 10
