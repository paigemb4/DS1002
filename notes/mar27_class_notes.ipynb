# %% [markdown]
# <a href="https://colab.research.google.com/github/paigemb4/DS1002/blob/main/notes/mar27_class_notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
import sys
sys.getsizeof(iris)
#this gives the size of the data frame in bytes
# Out:
# 14744

# %% [markdown]
# apply lambda functions w/ .apply()

# %%
(lambda x: x**2) (3)
#give it variable, then colon then function, then apply it to a number
#same as any other function it just doesn't have a name
# Out:
# 9

# %%
high_ord_func = lambda x, func: x + func(x)
high_ord_func(23, lambda x: x * x)
# Out:
# 552

# %%
iris['sepal_len_sq'] = iris.sepal_length.apply(lambda x: x**2)
iris.head(5)
#.apply() applies it to all things in the series
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  sepal_len_sq
# 0           5.1          3.5           1.4          0.2  setosa         26.01
# 1           4.9          3.0           1.4          0.2  setosa         24.01
# 2           4.7          3.2           1.3          0.2  setosa         22.09
# 3           4.6          3.1           1.5          0.2  setosa         21.16
# 4           5.0          3.6           1.4          0.2  setosa         25.00

# %%
iris['sepal_len_wid_avg'] = iris[['sepal_length','sepal_width']].apply(lambda x: (x.sepal_length+x.sepal_width)/2, axis=1)
iris.head()
#this computes the average of sepal_length and sepal_width
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  sepal_len_sq  \
# 0           5.1          3.5           1.4          0.2  setosa         26.01
# 1           4.9          3.0           1.4          0.2  setosa         24.01
# 2           4.7          3.2           1.3          0.2  setosa         22.09
# 3           4.6          3.1           1.5          0.2  setosa         21.16
# 4           5.0          3.6           1.4          0.2  setosa         25.00
#
#    sepal_len_wid_avg
# 0               4.30
# 1               3.95
# 2               3.95
# 3               3.85
# 4               4.30

# %% [markdown]
# practice:
#
# Use apply() to append a new column that is the minimum of (petal_length, petal_width)
#
# Print the head, tail of the new dataframe to check things look correct.

# %%
iris['petal_len_wid_minimum'] = iris[['petal_length','petal_width']].apply(lambda x: min(x.petal_length, x.petal_width), axis=1)
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  sepal_len_sq  \
# 0           5.1          3.5           1.4          0.2  setosa         26.01
# 1           4.9          3.0           1.4          0.2  setosa         24.01
# 2           4.7          3.2           1.3          0.2  setosa         22.09
# 3           4.6          3.1           1.5          0.2  setosa         21.16
# 4           5.0          3.6           1.4          0.2  setosa         25.00
#
#    sepal_len_wid_avg  petal_len_wid_minimum
# 0               4.30                    0.2
# 1               3.95                    0.2
# 2               3.95                    0.2
# 3               3.85                    0.2
# 4               4.30                    0.2

# %% [markdown]
# **aggregation**

# %% [markdown]
# .groupby()

# %%
iris.groupby("species").mean()
#output is itself a new dataframe
# Out:
#             sepal_length  sepal_width  petal_length  petal_width  \
# species
# setosa             5.006        3.428         1.462        0.246
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026
#
#             sepal_len_sq  sepal_len_wid_avg  petal_len_wid_minimum
# species
# setosa           25.1818              4.217                  0.246
# versicolor       35.4972              4.353                  1.326
# virginica        43.7980              4.781                  2.026

# %% [markdown]
# pd.pivot_table()

# %%
df = pd.DataFrame({"A": ["foo", "foo", "foo", "foo", "foo",
                         "bar", "bar", "bar", "bar"],
                   "B": ["one", "one", "one", "two", "two",
                         "one", "one", "two", "two"],
                   "C": ["small", "large", "large", "small",
                         "small", "large", "small", "small",
                         "large"],
                   "D": [1, 2, 2, 3, 3, 4, 5, 6, 7],
                   "E": [2, 4, 5, 5, 6, 6, 8, 9, 9]})

print(df)
table = pd.pivot_table(df, values='D', index=['A', 'B'],
                       columns=['C'], aggfunc="sum")
table
#c has values small or large which are now the variables
#values in the table come from column d, e is ignored
#aggregate function sums all of the values
# Out:
#      A    B      C  D  E
# 0  foo  one  small  1  2
# 1  foo  one  large  2  4
# 2  foo  one  large  2  5
# 3  foo  two  small  3  5
# 4  foo  two  small  3  6
# 5  bar  one  large  4  6
# 6  bar  one  small  5  8
# 7  bar  two  small  6  9
# 8  bar  two  large  7  9
# C        large  small
# A   B
# bar one    4.0    5.0
#     two    7.0    6.0
# foo one    4.0    1.0
#     two    NaN    6.0

# %%
pd.pivot_table(iris, values="sepal_length", columns=["species"], aggfunc = np.mean)
#takes the mean sepal length for each species
# Out:
# species       setosa  versicolor  virginica
# sepal_length   5.006       5.936      6.588

# %% [markdown]
# practice:
#
# Use a pivot table to compute the following statistics on sepal_width and petal_width grouped by species:
#
# median,mean
#
# These can be computed together in a single call to pivot_table().

# %%
pd.pivot_table(iris, values= ["sepal_width", "petal_width"], columns=["species"],aggfunc = [np.mean, np.median])
# Out:
#               mean                      median
# species     setosa versicolor virginica setosa versicolor virginica
# petal_width  0.246      1.326     2.026    0.2        1.3       2.0
# sepal_width  3.428      2.770     2.974    3.4        2.8       3.0

# %% [markdown]
# Stacking and Unstacking

# %%
iris_w_idx = iris.copy()

# Give the original index a name
iris_w_idx.index.name = 'obs_id'

# Create a multi-index, using `species` as part of the key.
iris_w_idx = iris_w_idx.reset_index().set_index(['species','obs_id'])

# %%
iris_w_idx
# Out:
#                   sepal_length  sepal_width  petal_length  petal_width  \
# species   obs_id
# setosa    0                5.1          3.5           1.4          0.2
#           1                4.9          3.0           1.4          0.2
#           2                4.7          3.2           1.3          0.2
#           3                4.6          3.1           1.5          0.2
#           4                5.0          3.6           1.4          0.2
# ...                        ...          ...           ...          ...
# virginica 145              6.7          3.0           5.2          2.3
#           146              6.3          2.5           5.0          1.9
#           147              6.5          3.0           5.2          2.0
#           148              6.2          3.4           5.4          2.3
#           149              5.9          3.0           5.1          1.8
#
#                   sepal_len_sq  sepal_len_wid_avg  petal_len_wid_minimum
# species   obs_id
# setosa    0              26.01               4.30                    0.2
#           1              24.01               3.95                    0.2
#           2              22.09               3.95                    0.2
#           3              21.16               3.85                    0.2
#           4              25.00               4.30                    0.2
# ...                        ...                ...                    ...
# virginica 145            44.89               4.85                    2.3
#           146            39.69               4.40                    1.9
#           147            42.25               4.75                    2.0
#           148            38.44               4.80                    2.3
#           149            34.81               4.45                    1.8
#
# [150 rows x 7 columns]

# %% [markdown]
# .unstack()

# %%
iris_wide = iris_w_idx.sepal_length.unstack(fill_value=0).T
#.T stands for transpose, switchs rows and columns

# %%
iris_wide
# Out:
# species  setosa  versicolor  virginica
# obs_id
# 0           5.1         0.0        0.0
# 1           4.9         0.0        0.0
# 2           4.7         0.0        0.0
# 3           4.6         0.0        0.0
# 4           5.0         0.0        0.0
# ...         ...         ...        ...
# 145         0.0         0.0        6.7
# 146         0.0         0.0        6.3
# 147         0.0         0.0        6.5
# 148         0.0         0.0        6.2
# 149         0.0         0.0        5.9
#
# [150 rows x 3 columns]

# %% [markdown]
# .stack()

# %%
iris_wide.T.stack().to_frame('sepal_length')
# Out:
#                   sepal_length
# species   obs_id
# setosa    0                5.1
#           1                4.9
#           2                4.7
#           3                4.6
#           4                5.0
# ...                        ...
# virginica 145              6.7
#           146              6.3
#           147              6.5
#           148              6.2
#           149              5.9
#
# [450 rows x 1 columns]

# %% [markdown]
# combining data frames

# %% [markdown]
# pd.concat()

# %%
df1 = pd.DataFrame(np.random.randn(3, 4))
df2 = pd.DataFrame(np.random.randn(3, 4))

print(df1)
print('-'*45)
print(df2)

df3 = pd.concat([df1, df2], axis=0)
#vertically stacks
print('-'*45)
print(df3)
# Out:
#           0         1         2         3
# 0 -1.035455 -1.605143 -0.207781  0.195637
# 1  0.849113  0.103662  1.530020 -1.687472
# 2 -1.150260  0.132139  2.388486 -0.230548
# ---------------------------------------------
#           0         1         2         3
# 0 -1.037255 -0.461548  1.167772 -0.300007
# 1 -0.963820 -0.150004  2.322197 -0.155790
# 2 -0.047901  0.476020 -0.455399 -0.446857
# ---------------------------------------------
#           0         1         2         3
# 0 -1.035455 -1.605143 -0.207781  0.195637
# 1  0.849113  0.103662  1.530020 -1.687472
# 2 -1.150260  0.132139  2.388486 -0.230548
# 0 -1.037255 -0.461548  1.167772 -0.300007
# 1 -0.963820 -0.150004  2.322197 -0.155790
# 2 -0.047901  0.476020 -0.455399 -0.446857

# %%
df4 = pd.concat([df1,df2], axis = 1, keys = ['foo', 'bar'])
df4
# Out:
#         foo                                     bar                      \
#           0         1         2         3         0         1         2
# 0 -1.035455 -1.605143 -0.207781  0.195637 -1.037255 -0.461548  1.167772
# 1  0.849113  0.103662  1.530020 -1.687472 -0.963820 -0.150004  2.322197
# 2 -1.150260  0.132139  2.388486 -0.230548 -0.047901  0.476020 -0.455399
#
#
#           3
# 0 -0.300007
# 1 -0.155790
# 2 -0.446857

# %%
df4.foo
# Out:
#           0         1         2         3
# 0 -1.035455 -1.605143 -0.207781  0.195637
# 1  0.849113  0.103662  1.530020 -1.687472
# 2 -1.150260  0.132139  2.388486 -0.230548

# %%
df4.bar
# Out:
#           0         1         2         3
# 0 -1.037255 -0.461548  1.167772 -0.300007
# 1 -0.963820 -0.150004  2.322197 -0.155790
# 2 -0.047901  0.476020 -0.455399 -0.446857

# %% [markdown]
# .merge()

# %%
left = pd.DataFrame({"key": ["jamie", "bill"], "lval": [15, 22]})
right = pd.DataFrame({"key": ["jamie", "bill", "asher"], "rval": [4, 5, 8]})

joined = pd.merge(left, right, on="key", how="right")

print('---left')
print(left)
print('\n---right')
print(right)
print('\n---joined')
print(joined)
# Out:
# ---left
#      key  lval
# 0  jamie    15
# 1   bill    22
#
# ---right
#      key  rval
# 0  jamie     4
# 1   bill     5
# 2  asher     8
#
# ---joined
#      key  lval  rval
# 0  jamie  15.0     4
# 1   bill  22.0     5
# 2  asher   NaN     8

# %%
left = pd.DataFrame({"key": ["jamie", "bill"], "val": [15, 22]})
right = pd.DataFrame({"key": ["jamie", "bill", "asher"], "val": [4, 5, 8]})

joined = pd.merge(left, right, on="key", how="right")

print('---left')
print(left)
print('\n---right')
print(right)
print('\n---joined')
print(joined)
#column names change
# Out:
# ---left
#      key  val
# 0  jamie   15
# 1   bill   22
#
# ---right
#      key  val
# 0  jamie    4
# 1   bill    5
# 2  asher    8
#
# ---joined
#      key  val_x  val_y
# 0  jamie   15.0      4
# 1   bill   22.0      5
# 2  asher    NaN      8

# %% [markdown]
# .join()

# %%
left2 = left.set_index('key').rename(columns={'val':'val_1'})
right2 = right.set_index('key').rename(columns={'val':'val_2'})

# %%
left2
# Out:
#        val_1
# key
# jamie     15
# bill      22

# %%
right2
# Out:
#        val_2
# key
# jamie      4
# bill       5
# asher      8

# %%
right2.join(left2) # defaults to first df (right2 in this case)
# Out:
#        val_2  val_1
# key
# jamie      4   15.0
# bill       5   22.0
# asher      8    NaN

# %%
right2.join(left2, how = 'inner')
# Out:
#        val_2  val_1
# key
# jamie      4     15
# bill       5     22

# %% [markdown]
# practice:
#
# Redo the join exercise above, using an outer join instead of an inner join.
# Make sure the results make sense.

# %%
right2.join(left2, how = 'outer')
# Out:
#        val_2  val_1
# key
# asher      8    NaN
# bill       5   22.0
# jamie      4   15.0

# %% [markdown]
# .reshape()

# %%
# create a series
ser = pd.Series([1, 1, 2, 3, 5, 8])

# extract values
vals = ser.values

print('orig data:', vals)
print('orig type:', type(vals))
print('orig shape:', vals.shape)

# reshaping series
reshaped_vals = vals.reshape((3, 2))

print('\n reshaped vals:')
print(reshaped_vals)
print('\n new type:', type(reshaped_vals))
print('new shape:', reshaped_vals.shape)
# Out:
# orig data: [1 1 2 3 5 8]
# orig type: <class 'numpy.ndarray'>
# orig shape: (6,)
#
#  reshaped vals:
# [[1 1]
#  [2 3]
#  [5 8]]
#
#  new type: <class 'numpy.ndarray'>
# new shape: (3, 2)

# %%
vals.reshape(-1,3)
#enfore 3 columns
# Out:
# array([[1, 1, 2],
#        [3, 5, 8]])

# %%
vals.reshape(3,-1)
#enforce 3 rows
# Out:
# array([[1, 1],
#        [2, 3],
#        [5, 8]])

# %% [markdown]
# **categoricals**

# %% [markdown]
# get_dummies()

# %%
cats = pd.DataFrame({'breed':['persian','persian','siamese','himalayan','burmese']})

print('--categorical data')
print(cats)

cats = pd.get_dummies(cats.breed, prefix='breed')

print('\n')
print('--dummified categorical data')
print(cats)
# Out:
# --categorical data
#        breed
# 0    persian
# 1    persian
# 2    siamese
# 3  himalayan
# 4    burmese
#
#
# --dummified categorical data
#    breed_burmese  breed_himalayan  breed_persian  breed_siamese
# 0              0                0              1              0
# 1              0                0              1              0
# 2              0                0              0              1
# 3              0                1              0              0
# 4              1                0              0              0

# %%
cats2 = pd.DataFrame({'breed':['persian','persian','siamese','himalayan','burmese'],
                      'color':['calico','white','seal point','cream','sable']})
cats2
# Out:
#        breed       color
# 0    persian      calico
# 1    persian       white
# 2    siamese  seal point
# 3  himalayan       cream
# 4    burmese       sable
